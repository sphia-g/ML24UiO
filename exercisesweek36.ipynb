# %% [markdown]
# # Exercises week 36
# **September 2-6, 2024**
#
# Date: **Deadline is Friday September 6 at midnight**

# %% [markdown]
# ## Overarching aims of the exercises this week
#
# This set of exercises form an important part of the first project. The
# analytical exercises deal with the material covered last week on the
# mathematical interpretations of ordinary least squares and of Ridge
# regression. The numerical exercises can be seen as a continuation of
# exercise 3 from week 35, with the inclusion of Ridge regression. This
# material enters also the discussions of the first project.

# %% [markdown]
# ## Exercise 1: Analytical exercises
#
# The aim here is to derive the expression for the optimal parameters
# using Ridge regression. Furthermore, using the singular value
# decomposition, we will analyze the difference between the ordinary
# least squares approach and Ridge regression.
#
# The expression for the standard Mean Squared Error (MSE) which we used to define our cost function and the equations for the ordinary least squares (OLS) method, was given by the
# optimization problem

# %% [markdown]
# $$
# {\displaystyle \min_{\boldsymbol{\beta}\in {\mathbb{R}}^{p}}}\frac{1}{n}\left\{\left(\boldsymbol{y}-\boldsymbol{X}\boldsymbol{\beta}\right)^T\left(\boldsymbol{y}-\boldsymbol{X}\boldsymbol{\beta}\right)\right\}.
# $$

# %% [markdown]
# which we can also write as

# %% [markdown]
# $$
# {\displaystyle \min_{\boldsymbol{\beta}\in
# {\mathbb{R}}^{p}}}\frac{1}{n}\sum_{i=0}^{n-1}\left(y_i-\tilde{y}_i\right)^2=\frac{1}{n}\vert\vert \boldsymbol{y}-\boldsymbol{X}\boldsymbol{\beta}\vert\vert_2^2,
# $$

# %% [markdown]
# where we have used the definition of  a norm-2 vector, that is

# %% [markdown]
# $$
# \vert\vert \boldsymbol{x}\vert\vert_2 = \sqrt{\sum_i x_i^2}.
# $$

# %% [markdown]
# By minimizing the above equation with respect to the parameters
# $\boldsymbol{\beta}$ we could then obtain an analytical expression for the
# parameters $\boldsymbol{\beta}$.
#
# We can add a regularization parameter $\lambda$ by
# defining a new cost function to be optimized, that is

# %% [markdown]
# $$
# {\displaystyle \min_{\boldsymbol{\beta}\in
# {\mathbb{R}}^{p}}}\frac{1}{n}\vert\vert \boldsymbol{y}-\boldsymbol{X}\boldsymbol{\beta}\vert\vert_2^2+\lambda\vert\vert \boldsymbol{\beta}\vert\vert_2^2
# $$

# %% [markdown]
# which leads to the Ridge regression minimization problem. One can require as part of the optimization problem
# that $\vert\vert \boldsymbol{\beta}\vert\vert_2^2\le t$, where $t$ is
# a finite number larger than zero. We will not implement that here.

# %% [markdown]
# ### a) Expression for Ridge regression
#
# Show that the optimal parameters

# %% [markdown]
# $$
# \hat{\boldsymbol{\beta}}_{\mathrm{Ridge}} = \left(\boldsymbol{X}^T\boldsymbol{X}+\lambda\boldsymbol{I}\right)^{-1}\boldsymbol{X}^T\boldsymbol{y},
# $$

# %% [markdown]
# with $\boldsymbol{I}$ being a $p\times p$ identity matrix with the constraint that

# %% [markdown]
# $$
# \sum_{i=0}^{p-1} \beta_i^2 \leq t,
# $$

# %% [markdown]
# with $t$ a finite positive number. In the optimization, we will not require that the latter is satisfied.
#
# The ordinary least squares result is

# %% [markdown]
# $$
# \hat{\boldsymbol{\beta}}_{\mathrm{OLS}} = \left(\boldsymbol{X}^T\boldsymbol{X}\right)^{-1}\boldsymbol{X}^T\boldsymbol{y},
# $$

# %% [markdown]
# Answer to 1a)
#
# To find the
# $ {\boldsymbol{\beta}}
# $
# that minimizes the ridge function, we need to use the cost function:
#
# $$
# {\displaystyle \min_{\boldsymbol{\beta}\in
# {\mathbb{R}}^{p}}}\frac{1}{n}\vert\vert \boldsymbol{y}-\boldsymbol{X}\boldsymbol{\beta}\vert\vert_2^2+\lambda\vert\vert \boldsymbol{\beta}\vert\vert_2^2
# .
# $$
#
# First we differentiating this expression with respect to
# $ {\boldsymbol{\beta}}
# $
# , and set the derivative equal to zero. We then solve for
# $ {\boldsymbol{\beta}}
# $
# , and have thus found the optimal parameters for the ridge expression.
# From the cost function, we see that the function we will be working with is this:
# $$
# \vert\vert \boldsymbol{y}-\boldsymbol{X}\boldsymbol{\beta}\vert\vert_2^2+\lambda\vert\vert \boldsymbol{\beta}\vert\vert_2^2
# .
# $$
#  Before differentiating, we have to expand the term.
#
# $$
# \begin{align} \vert\vert \boldsymbol{y}-\boldsymbol{X}\boldsymbol{\beta}\vert\vert_2^2+\lambda\vert\vert \boldsymbol{\beta}\vert\vert_2^2
# &= \vert\vert \boldsymbol{y} \vert\vert_2^2 -2\boldsymbol{y}^T\boldsymbol{X}\boldsymbol{\beta} + \vert\vert \boldsymbol{X}\boldsymbol{\beta} \vert\vert_2^2 + {\lambda} \vert\vert \boldsymbol{\beta}\vert\vert_2^2 \\
#
# &= \boldsymbol{y}^T\boldsymbol{y} - 2\boldsymbol{y}^T\boldsymbol{X}\boldsymbol{\beta} + (\boldsymbol{X} \boldsymbol{\beta})^T(\boldsymbol{X} \boldsymbol{\beta}) + {\lambda} \vert\vert \boldsymbol{\beta}\vert\vert_2^2 \\
# &= \boldsymbol{y}^T\boldsymbol{y} - 2\boldsymbol{y}^T\boldsymbol{X}\boldsymbol{\beta} + \boldsymbol{\beta}^T \boldsymbol{X}^T \boldsymbol{X} \boldsymbol{\beta} + {\lambda} \vert\vert \boldsymbol{\beta}\vert\vert_2^2 \\
#
# \end{align}
# $$
#
# Will now differentiate the expression and set it equal to 0.
#
# $$
# \begin{align}
# \frac{\delta}{\delta\beta} (\boldsymbol{y}^T\boldsymbol{y} - 2\boldsymbol{y}^T\boldsymbol{X}\boldsymbol{\beta} + \boldsymbol{\beta}^T \boldsymbol{X}^T \boldsymbol{X} \boldsymbol{\beta} + {\lambda} \vert\vert \boldsymbol{\beta}\vert\vert_2^2 )
# &= \frac{\delta}{\delta\beta} (\boldsymbol{y}^T\boldsymbol{y}) - 2\frac{\delta}{\delta\beta} (\boldsymbol{y}^T\boldsymbol{X}\boldsymbol{\beta}) + \frac{\delta}{\delta\beta}(\boldsymbol{\beta}^T \boldsymbol{X}^T \boldsymbol{X} \boldsymbol{\beta}) + \frac{\delta}{\delta\beta}({\lambda} \vert\vert \boldsymbol{\beta}\vert\vert_2^2) \\
# &= 0 - 2\boldsymbol{y}^T\boldsymbol{X} + (\boldsymbol{X}^T\boldsymbol{X}+(\boldsymbol{X}^T\boldsymbol{X})^T\boldsymbol{\beta}) + 2\lambda\boldsymbol{\beta}
# \\
# &=-2\boldsymbol{y}^T\boldsymbol{X} + 2(\boldsymbol{X}^T\boldsymbol{X}\boldsymbol{\beta}) + 2\lambda\boldsymbol{\beta} \\
# \end{align}
# $$
#
# Setting (3) equal to zero.
# $$
# \begin{align}
# -2\boldsymbol{y}^T\boldsymbol{X} + 2(\boldsymbol{X}^T\boldsymbol{X}\boldsymbol{\beta}) + 2\lambda\boldsymbol{\beta} = 0 \\
# 2\boldsymbol{X}^T\boldsymbol{X}\boldsymbol{\beta} + 2\lambda\boldsymbol{\beta} = 2\boldsymbol{y}^T\boldsymbol{X} \\
# (\boldsymbol{X}^T\boldsymbol{X} + \lambda \boldsymbol{I})\boldsymbol{\beta} = \boldsymbol{X}^T\boldsymbol{y}\\
# (\boldsymbol{X}^T\boldsymbol{X} + \lambda \boldsymbol{I})^{-1}(\boldsymbol{X}^T\boldsymbol{X} + \lambda \boldsymbol{I})\boldsymbol{\beta} = (\boldsymbol{X}^T\boldsymbol{X} + \lambda \boldsymbol{I})^{-1}\boldsymbol{X}^T\boldsymbol{y}\\
# \boldsymbol{\beta} = (\boldsymbol{X}^T\boldsymbol{X} + \lambda \boldsymbol{I})^{-1}\boldsymbol{X}^T\boldsymbol{y}
# \end{align}
# $$
# We have now proved what we wanted to prove.

# %% [markdown]
# ### b) The singular value decomposition
#
# Here we will use the singular value decomposition of an $n\times p$ matrix $\boldsymbol{X}$ (our design matrix)

# %% [markdown]
# $$
# \boldsymbol{X}=\boldsymbol{U}\boldsymbol{\Sigma}\boldsymbol{V}^T,
# $$

# %% [markdown]
# to study properties of Ridge regression and ordinary least squares regression.
# Here $\boldsymbol{U}$ and $\boldsymbol{V}$ are orthogonal matrices of dimensions
# $n\times n$ and $p\times p$, respectively, and $\boldsymbol{\Sigma}$ is an
# $n\times p$ matrix which contains the singular values only. This material was discussed during the lectures of week 35.
#
# Show that you can write the
# OLS solutions in terms of the eigenvectors (the columns) of the orthogonal matrix  $\boldsymbol{U}$ as

# %% [markdown]
# $$
# \tilde{\boldsymbol{y}}_{\mathrm{OLS}}=\boldsymbol{X}\boldsymbol{\beta}  = \sum_{j=0}^{p-1}\boldsymbol{u}_j\boldsymbol{u}_j^T\boldsymbol{y}.
# $$

# %% [markdown]
# As we already have shown that
# $$
# \hat{\boldsymbol{\beta}}_{\mathrm{OLS}} = \left(\boldsymbol{X}^T\boldsymbol{X}\right)^{-1}\boldsymbol{X}^T\boldsymbol{y},
# $$
#
# we put this beta into the equation:
# $$
# \tilde{\boldsymbol{y}}_{\mathrm{OLS}} = \boldsymbol{X}\boldsymbol{\beta}  = \boldsymbol{X}\left(\boldsymbol{X}^T\boldsymbol{X}\right)^{-1}\boldsymbol{X}^T\boldsymbol{y}
# $$

# %% [markdown]
# And now using single value decomposition, we put in
# $$
# \boldsymbol{X}=\boldsymbol{U}\boldsymbol{\Sigma}\boldsymbol{V}^T,
# $$
# for X.

# %% [markdown]
# ![alt text](image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Here $$ \boldsymbol{u_i} $$ is the i-th column vector of the matrix U. We take the sum ut to p singular values, and the first p columns of U make up the basis of the column space of our design matrix.

# %% [markdown]
# For Ridge regression, show that the corresponding equation is

# %% [markdown]
# $$
# \tilde{\boldsymbol{y}}_{\mathrm{Ridge}}=\boldsymbol{X}\boldsymbol{\beta}_{\mathrm{Ridge}} = \boldsymbol{U\Sigma V^T}\left(\boldsymbol{V}\boldsymbol{\Sigma}^2\boldsymbol{V}^T+\lambda\boldsymbol{I} \right)^{-1}(\boldsymbol{U\Sigma V^T})^T\boldsymbol{y}=\sum_{j=0}^{p-1}\boldsymbol{u}_j\boldsymbol{u}_j^T\frac{\sigma_j^2}{\sigma_j^2+\lambda}\boldsymbol{y},
# $$

# %% [markdown]
# ![alt text](image-1.png)

# %% [markdown]
# with the vectors $\boldsymbol{u}_j$ being the columns of $\boldsymbol{U}$ from the SVD of the matrix $\boldsymbol{X}$.
#
# Give an interpretation of the results.  [Section 3.4 of Hastie et al's textbook gives a good discussion of the above results](https://link.springer.com/book/10.1007/978-0-387-84858-7).

# %% [markdown]
# ## Exercise 2: Adding Ridge Regression
#
# This exercise is a continuation of exercise 3 from week 35, see <https://compphysics.github.io/MachineLearning/doc/LectureNotes/_build/html/exercisesweek35.html>. We will use the same function to
# generate our data set, still staying with a simple function $y(x)$
# which we want to fit using linear regression, but now extending the
# analysis to include the Ridge regression method.
#
# In this exercise you need to include the same elements from last week, that is
# 1. scale your data by subtracting the mean value from each column in the design matrix.
#
# 2. perform a split of the data in a training set and a test set.
#
# The addition to the analysis this time is the introduction of the hyperparameter $\lambda$ when introducing Ridge regression.
#
# Extend the code from exercise 3 from [week 35](https://compphysics.github.io/MachineLearning/doc/LectureNotes/_build/html/exercisesweek35.html) to include Ridge regression with the hyperparameter $\lambda$. The optimal parameters $\hat{\beta}$ for Ridge regression can be obtained by matrix inversion in a similar way as done for ordinary least squares. You need to add to your code the following equations

# %% [markdown]
# $$
# \hat{\boldsymbol{\beta}}_{\mathrm{Ridge}} = \left(\boldsymbol{X}^T\boldsymbol{X}+\lambda\boldsymbol{I}\right)^{-1}\boldsymbol{X}^T\boldsymbol{y}.
# $$

# %% [markdown]
# The ordinary least squares result you encoded last week is given by

# %% [markdown]
# $$
# \hat{\boldsymbol{\beta}}_{\mathrm{OLS}} = \left(\boldsymbol{X}^T\boldsymbol{X}\right)^{-1}\boldsymbol{X}^T\boldsymbol{y},
# $$

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

def R2(y_data, y_model):
    return 1 - np.sum((y_data - y_model) ** 2) / np.sum((y_data - np.mean(y_data)) ** 2)
def MSE(y_data,y_model):
    n = np.size(y_model)
    return np.sum((y_data-y_model)**2)/n
# def lambda()

np.random.seed()

n = 100
# Make data set.
x = np.linspace(-3, 3, n).reshape(-1, 1)
y = np.exp(-x**2) + 1.5 * np.exp(-(x-2)**2)+ np.random.normal(0, 0.1, x.shape)

# Design matrix as a function of a fifth-order polynomial
X = np.zeros((len(x), 6))
X[:, 0] = 1.0          # x^0 (intercept term)
X[:, 1] = x[:, 0]      # x^1
X[:, 2] = x[:, 0]**2   # x^2
X[:, 3] = x[:, 0]**3   # x^3
X[:, 4] = x[:, 0]**4   # x^4
X[:, 5] = x[:, 0]**5   # x^5

# Subtract the mean value from each column of the design matrix
X[:, 1:] = X[:, 1:] - np.mean(X[:, 1:], axis=0)

# We split the data into test and training data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Choose lambda and then trial and error to find the best lambda
lambda_param = 1.0

# Identity matrix of the same size as X-train.T @ X-train
I = np.eye(X_train.shape[1])

# matrix inversion to find beta
beta_ridge = np.linalg.inv(X_train.T @ X_train + lambda_param * I) @ X_train.T @ y_train
print("Ridge Regression Coefficients:", beta_ridge)

# and then make the prediction
ytilde = X_train @ beta
print("Training R2")
print(R2(y_train,ytilde))
print("Training MSE")
print(MSE(y_train,ytilde))

ypredict = X_test @ beta
print("Test R2")
print(R2(y_test,ypredict))
print("Test MSE")
print(MSE(y_test,ypredict))
# Out:
# Ridge Regression Coefficients: [[ 0.68107609]
#  [ 0.26279803]
#  [-0.01952899]
#  [ 0.06000418]
#  [-0.00268327]
#  [-0.00930793]]
# Training R2
# 0.843249048797538
# Training MSE
# 0.043063523486728324
# Test R2
# 0.8243309787387261
# Test MSE
# 0.0396724101470139

# %% [markdown]
# Use these results to compute the mean squared error for ordinary least
# squares and Ridge regression first for a polynomial of degree five
# with $n=100$ data points and five selected values of
# $\lambda=[0.0001,0.001, 0.01,0.1,1.0]$. Compute thereafter the mean
# squared error for the same values of $\lambda$ for polynomials of degree ten
# and $15$. Discuss your results for the training MSE and test MSE with
# Ridge regression and ordinary least squares.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

def R2(y_data, y_model):
    return 1 - np.sum((y_data - y_model) ** 2) / np.sum((y_data - np.mean(y_data)) ** 2)

def MSE(y_data, y_model):
    n = np.size(y_model)
    return np.sum((y_data - y_model) ** 2) / n

np.random.seed()

n = 100
# Make data set
x = np.linspace(-3, 3, n).reshape(-1, 1)
y = np.exp(-x**2) + 1.5 * np.exp(-(x-2)**2) + np.random.normal(0, 0.1, x.shape)

# Define a function to create the design matrix for a given polynomial degree
def create_design_matrix(x, degree):
    X = np.zeros((len(x), degree + 1))
    for i in range(degree + 1):
        X[:, i] = x[:, 0]**i
    # Subtract the mean from each column except the intercept
    X[:, 1:] = X[:, 1:] - np.mean(X[:, 1:], axis=0)
    return X

# Set the lambda values
lambda_values = [0.0001, 0.001, 0.01, 0.1, 1.0]

# Function to compute MSE for a given degree
def compute_mse_for_degree(degree):
    X = create_design_matrix(x, degree)
    
    # Split the data into test and training data
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    # Ordinary Least Squares (OLS)
    beta_ols = np.linalg.inv(X_train.T @ X_train) @ X_train.T @ y_train
    mse_train_ols = MSE(y_train, X_train @ beta_ols)
    mse_test_ols = MSE(y_test, X_test @ beta_ols)
    
    print(f"OLS Training MSE for degree {degree}:", mse_train_ols)
    print(f"OLS Test MSE for degree {degree}:", mse_test_ols)
    
    # Ridge Regression for different values of lambda
    mse_train_ridge = []
    mse_test_ridge = []
    
    for lambda_param in lambda_values:
        I = np.eye(X_train.shape[1])
        beta_ridge = np.linalg.inv(X_train.T @ X_train + lambda_param * I) @ X_train.T @ y_train
        
        # Compute MSE for training and test sets
        mse_train = MSE(y_train, X_train @ beta_ridge)
        mse_test = MSE(y_test, X_test @ beta_ridge)
        
        mse_train_ridge.append(mse_train)
        mse_test_ridge.append(mse_test)
        
        print(f"Ridge Regression with lambda={lambda_param} for degree {degree}:")
        print("Training MSE:", mse_train)
        print("Test MSE:", mse_test)
    
    # Plot the results for this degree
    plt.figure(figsize=(10, 6))
    plt.plot(lambda_values, mse_train_ridge, label="Train MSE (Ridge)", marker='o')
    plt.plot(lambda_values, mse_test_ridge, label="Test MSE (Ridge)", marker='o')
    plt.axhline(y=mse_train_ols, color='r', linestyle='--', label="Train MSE (OLS)")
    plt.axhline(y=mse_test_ols, color='b', linestyle='--', label="Test MSE (OLS)")
    plt.xscale('log')
    plt.xlabel('Lambda')
    plt.ylabel('Mean Squared Error')
    plt.title(f'MSE for OLS and Ridge Regression with Varying Lambda (Degree {degree})')
    plt.legend()
    plt.show()

# Compute MSE for degrees 5, 10, and 15
for degree in [5, 10, 15]:
    compute_mse_for_degree(degree)
# Out:
# OLS Training MSE for degree 5: 0.02044604066151892
# OLS Test MSE for degree 5: 0.01757679167803198
# Ridge Regression with lambda=0.0001 for degree 5:
# Training MSE: 0.020446040662929477
# Test MSE: 0.017576843282158194
# Ridge Regression with lambda=0.001 for degree 5:
# Training MSE: 0.020446040802563452
# Test MSE: 0.01757730780671202
# Ridge Regression with lambda=0.01 for degree 5:
# Training MSE: 0.020446054754457536
# Test MSE: 0.017581961699642
# Ridge Regression with lambda=0.1 for degree 5:
# Training MSE: 0.020447438567924515
# Test MSE: 0.0176293582738956
# Ridge Regression with lambda=1.0 for degree 5:
# Training MSE: 0.020575585082457028
# Test MSE: 0.018182725775608394
# OLS Training MSE for degree 10: 0.00791383101127575
# OLS Test MSE for degree 10: 0.013176626877743028
# Ridge Regression with lambda=0.0001 for degree 10:
# Training MSE: 0.007913831138794913
# Test MSE: 0.013176857316976634
# Ridge Regression with lambda=0.001 for degree 10:
# ...

# %% [markdown]
# OLS corresponds to Ridge regression with $λ=0$, meaning no regularization is applied, and the model simply minimizes the sum of squared errors. For OLS, the training MSE is low because the model is allowed to fit the training data as closely as possible. The test MSE on the other hand is much higher, especially in higher polynomial degrees due to the effects of overfitting.
#
# Ridge regression introduces a regularization term controlled by $λ$, which penalizes large coefficients and discourages overfitting. When $λ$ is small, Ridge regression behaves similarly to OLS. As $λ$ increases, the Ridge regression model starts shrinking the coefficients, preventing overfitting. This leads to higher training MSE compared to OLS, as the model sacrifices some fit to reduce the complexity. An increase for larger $λ$ can be observed in all graphs. This shows that while a small amount of regularization can improve the test error, too much regularization leads to underfitting and higher test MSE.
#
# Finally we observe that MSE values of test and training set are flipped in the polynomial of degree 15. This is counterintuitive and we dont have a good explanation for that.
